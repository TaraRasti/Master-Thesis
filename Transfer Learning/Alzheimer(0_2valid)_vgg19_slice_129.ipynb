# %% [markdown]
# <a href="https://colab.research.google.com/github/TaraRasti/Master-Thesis/blob/main/Transfer%20Learning/Alzheimer(0_2valid)_vgg19_slice_129.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from __future__ import print_function, division
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.autograd import Variable
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from torchvision.datasets import ImageFolder
from torch.utils.data import Subset
from sklearn.model_selection import train_test_split
from torchvision.transforms import Compose, ToTensor, Resize
from torch.utils.data import DataLoader
from collections import defaultdict

plt.ion()  

use_gpu = torch.cuda.is_available()
if use_gpu:
    print("Using CUDA")
# Out:
# Using CUDA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
transform = transforms.Compose( [                                  
                                 transforms.Resize((224,224)),
                                 transforms.RandomRotation(10),
                                 transforms.RandomHorizontalFlip(), 
                                 transforms.ToTensor(),
                                  ])

def train_val_dataset(dataset, val_split=0.2):
    train_idx, val_idx = train_test_split(list(range(len(dataset))), test_size=val_split)
    datasets = {}
    datasets['train'] = Subset(dataset, train_idx)
    datasets['val'] = Subset(dataset, val_idx)
    return datasets

dataset = ImageFolder('/content/drive/MyDrive/129', transform=transform)
print('length of dataset :',len(dataset))
datasets = train_val_dataset(dataset)
print('length of trainset :',len(datasets['train']))
print('length of validation set :',len(datasets['val']))
print(dataset)
# Out:
# length of dataset : 1188
# length of trainset : 950
# length of validation set : 238
# Dataset ImageFolder
#     Number of datapoints: 1188
#     Root location: /content/drive/MyDrive/129
#     StandardTransform
# Transform: Compose(
#                Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=None)
#                RandomRotation(degrees=[-10.0, 10.0], interpolation=nearest, expand=False, fill=0)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#            )

# %%
dataloaders = {x:DataLoader(datasets[x], 16, shuffle=True, num_workers=4) for x in ['train','val']}
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
inputs, classes = next(iter(dataloaders['train']))
print(inputs.shape, classes.shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# torch.Size([16, 3, 224, 224]) torch.Size([16])

# %%
class_names = dataset.classes
print(class_names)
# Out:
# ['demented', 'normal']

# %%
dataset_sizes={'val':len(datasets['val']),'train':len(datasets['train'])}

# %%
def imshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    plt.figure(figsize=(25, 25))
    plt.axis('off')
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

def show_databatch(inputs, classes):
    out = torchvision.utils.make_grid(inputs)
    imshow(out, title=[class_names[x] for x in classes])

show_databatch(inputs, classes)

# %%
def visualize_model(vgg, num_images=6):
    was_training = vgg.training
    
    vgg.train(False)
    vgg.eval() 
    
    images_so_far = 0

    for i, data in enumerate(dataloaders['val']):
        inputs, labels = data
        size = inputs.size()[0]
        
        if use_gpu:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)
        
        outputs = vgg(inputs)
        
        _, preds = torch.max(outputs.data, 1)
        predicted_labels = [preds[j] for j in range(inputs.size()[0])]
        
        print("Ground truth:")
        show_databatch(inputs.data.cpu(), labels.data.cpu())
        print("Prediction:")
        show_databatch(inputs.data.cpu(), predicted_labels)
        
        del inputs, labels, outputs, preds, predicted_labels
        torch.cuda.empty_cache()
        
        images_so_far += size
        if images_so_far >= num_images:
            break
        
    vgg.train(mode=was_training)

# %%
def eval_model(vgg, criterion):
    since = time.time()
    avg_loss = 0
    avg_acc = 0
    loss_test = 0
    acc_test = 0
    
    test_batches = len(dataloaders['val'])
    print("Evaluating model")
    print('-' * 10)
    
    for i, data in enumerate(dataloaders['val']):
        if i % 10 == 0:
            print("\rTest batch {}/{}".format(i, test_batches), end='', flush=True)

        vgg.train(False)
        vgg.eval()
        inputs, labels = data

        if use_gpu:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)

        outputs = vgg(inputs)

        _, preds = torch.max(outputs.data, 1)
        loss = criterion(outputs, labels)

        loss_test += loss.item()
        acc_test += torch.sum(preds == labels.data).item()

        del inputs, labels, outputs, preds
        torch.cuda.empty_cache()
        
    avg_loss = loss_test / dataset_sizes['val']
    avg_acc = acc_test / dataset_sizes['val']
    
    elapsed_time = time.time() - since
    print()
    print("Evaluation completed in {:.0f}m {:.0f}s".format(elapsed_time // 60, elapsed_time % 60))
    print("Avg loss (test): {:.4f}".format(avg_loss))
    print("Avg acc (test): {:.4f}".format(avg_acc))
    print('-' * 10)

# %%
vgg19 = models.vgg19(pretrained=True)
print(vgg19.classifier[6].out_features)  


for param in vgg19.features.parameters():
    param.require_grad = False


num_features = vgg19.classifier[6].in_features
features = list(vgg19.classifier.children())[:-1] 
features.extend([nn.Linear(num_features, len(class_names))])
vgg19.classifier = nn.Sequential(*features)
print(vgg19)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
#   0%|          | 0.00/548M [00:00<?, ?B/s]
# 1000
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %%
if use_gpu:
    vgg19.cuda()
    
criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.Adam(vgg19.parameters(), lr=1e-5, weight_decay=1e-5)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
print("Test before training")
eval_model(vgg19, criterion)
# Out:
# Test before training
# Evaluating model
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Test batch 0/15
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Test batch 10/15
# Evaluation completed in 0m 25s
# Avg loss (test): 0.0418
# Avg acc (test): 0.6849
# ----------

# %%
history = defaultdict(list)

# %%
def train_model(vgg, criterion, optimizer, scheduler, num_epochs):
    since = time.time()
    best_model_wts = copy.deepcopy(vgg.state_dict())
    best_acc = 0.0
    
    avg_loss = 0
    avg_acc = 0
    avg_loss_val = 0
    avg_acc_val = 0
    
    train_batches = len(dataloaders['train'])
    val_batches = len(dataloaders['val'])
    
    for epoch in range(num_epochs):
        print("Epoch {}/{}".format(epoch, num_epochs))
        print('-' * 10)
        
        loss_train = 0
        loss_val = 0
        acc_train = 0
        acc_val = 0
        
        vgg.train(True)
        
        for i, data in enumerate(dataloaders['train']):
            if i % 10 == 0:
                print("\rTraining batch {}/{}".format(i, train_batches), end='', flush=True)
                
            if i >= train_batches:
                break
                
            inputs, labels = data
            
            if use_gpu:
                inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
            else:
                inputs, labels = Variable(inputs), Variable(labels)
            
            optimizer.zero_grad()
            
            outputs = vgg(inputs)
            
            _, preds = torch.max(outputs.data, 1)
            loss = criterion(outputs, labels)
            
            loss.backward()
            optimizer.step()
            
            loss_train += loss.item()
            acc_train += torch.sum(preds == labels.data).item()
            
            del inputs, labels, outputs, preds
            torch.cuda.empty_cache()
        
        print()

        avg_loss = loss_train / dataset_sizes['train']
        avg_acc = acc_train / dataset_sizes['train']
        
        vgg.train(False)
        vgg.eval()
            
        for i, data in enumerate(dataloaders['val']):
            if i % 10 == 0:
                print("\rValidation batch {}/{}".format(i, val_batches), end='', flush=True)
                
            inputs, labels = data
            
            if use_gpu:
                inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
            else:
                inputs, labels = Variable(inputs), Variable(labels)
            
            optimizer.zero_grad()
            
            outputs = vgg(inputs)
            
            _, preds = torch.max(outputs.data, 1)
            loss = criterion(outputs, labels)

            loss_val += loss.item()
            acc_val += torch.sum(preds == labels.data).item()

            del inputs, labels, outputs, preds
            torch.cuda.empty_cache()
        
        avg_loss_val = loss_val / dataset_sizes['val']
        avg_acc_val = acc_val / dataset_sizes['val']
        
        print()
        print("Epoch {} result: ".format(epoch))
        print("Avg loss (train): {:.4f}".format(avg_loss))
        print("Avg acc (train): {:.4f}".format(avg_acc))
        print("Avg loss (val): {:.4f}".format(avg_loss_val))
        print("Avg acc (val): {:.4f}".format(avg_acc_val))
        print('-' * 10)
        print()

        history['epoch'].append(epoch+1)
        history['avg_loss'].append(round(avg_loss,5))
        history['avg_acc'].append(round(avg_acc,5))
        history['avg_loss_val'].append(round(avg_loss_val,5))
        history['avg_acc_val'].append(round(avg_acc_val,5))
    
        
        if avg_acc_val > best_acc:
            best_acc = avg_acc_val
            best_model_wts = copy.deepcopy(vgg.state_dict())
        
    elapsed_time = time.time() - since
    print()
    print("Training completed in {:.0f}m {:.0f}s".format(elapsed_time // 60, elapsed_time % 60))
    print("Best acc: {:.4f}".format(best_acc))
    
    vgg.load_state_dict(best_model_wts)
    return vgg

# %%
def plot_results(history):
    avg_acc = history['avg_acc']
    avg_acc_val = history['avg_acc_val']
    avg_loss = history['avg_loss']
    avg_loss_val = history['avg_loss_val']
    epochs = history['epoch']

    plt.figure(figsize = (24, 6))
    plt.subplot(1,2,1)
    plt.plot(epochs, avg_acc, 'b', label = 'Training Accuracy')
    plt.plot(epochs, avg_acc_val, 'r', label = 'Validation Accuracy')
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')  
    
    plt.subplot(1,2,2)
    plt.plot(epochs, avg_loss, 'b', label = 'Training Loss')
    plt.plot(epochs, avg_loss_val, 'r', label = 'Validation Loss')
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')
    plt.show()

# %%
vgg19 = train_model(vgg19, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100)
# Out:
# Epoch 0/100
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Training batch 50/60
# Validation batch 10/15
# Epoch 0 result:
# Avg loss (train): 0.0330
# Avg acc (train): 0.7589
# Avg loss (val): 0.0292
# Avg acc (val): 0.7731
# ----------
#
# Epoch 1/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 1 result:
# Avg loss (train): 0.0286
# Avg acc (train): 0.7811
# Avg loss (val): 0.0284
# Avg acc (val): 0.8025
# ----------
#
# Epoch 2/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 2 result:
# Avg loss (train): 0.0261
# Avg acc (train): 0.8084
# Avg loss (val): 0.0276
# Avg acc (val): 0.8067
# ----------
#
# Epoch 3/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 3 result:
# Avg loss (train): 0.0248
# Avg acc (train): 0.8211
# Avg loss (val): 0.0294
# Avg acc (val): 0.7983
# ----------
#
# Epoch 4/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 4 result:
# Avg loss (train): 0.0218
# Avg acc (train): 0.8358
# Avg loss (val): 0.0257
# Avg acc (val): 0.8277
# ----------
#
# Epoch 5/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 5 result:
# Avg loss (train): 0.0219
# Avg acc (train): 0.8453
# Avg loss (val): 0.0277
# Avg acc (val): 0.8067
# ----------
#
# Epoch 6/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 6 result:
# Avg loss (train): 0.0183
# Avg acc (train): 0.8842
# Avg loss (val): 0.0314
# Avg acc (val): 0.8109
# ----------
#
# Epoch 7/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 7 result:
# Avg loss (train): 0.0184
# Avg acc (train): 0.8726
# Avg loss (val): 0.0269
# Avg acc (val): 0.8445
# ----------
#
# Epoch 8/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 8 result:
# Avg loss (train): 0.0160
# Avg acc (train): 0.8916
# Avg loss (val): 0.0264
# Avg acc (val): 0.8403
# ----------
#
# Epoch 9/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 9 result:
# Avg loss (train): 0.0126
# Avg acc (train): 0.9232
# Avg loss (val): 0.0249
# Avg acc (val): 0.8403
# ----------
#
# Epoch 10/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 10 result:
# Avg loss (train): 0.0116
# Avg acc (train): 0.9368
# Avg loss (val): 0.0374
# Avg acc (val): 0.7983
# ----------
#
# Epoch 11/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 11 result:
# Avg loss (train): 0.0085
# Avg acc (train): 0.9579
# Avg loss (val): 0.0313
# Avg acc (val): 0.8697
# ----------
#
# Epoch 12/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 12 result:
# Avg loss (train): 0.0070
# Avg acc (train): 0.9611
# Avg loss (val): 0.0280
# Avg acc (val): 0.8739
# ----------
#
# Epoch 13/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 13 result:
# Avg loss (train): 0.0064
# Avg acc (train): 0.9589
# Avg loss (val): 0.0325
# Avg acc (val): 0.8613
# ----------
#
# Epoch 14/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 14 result:
# Avg loss (train): 0.0087
# Avg acc (train): 0.9463
# Avg loss (val): 0.0237
# Avg acc (val): 0.8739
# ----------
#
# Epoch 15/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 15 result:
# Avg loss (train): 0.0064
# Avg acc (train): 0.9663
# Avg loss (val): 0.0312
# Avg acc (val): 0.8782
# ----------
#
# Epoch 16/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 16 result:
# Avg loss (train): 0.0033
# Avg acc (train): 0.9832
# Avg loss (val): 0.0374
# Avg acc (val): 0.8782
# ----------
#
# Epoch 17/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 17 result:
# Avg loss (train): 0.0054
# Avg acc (train): 0.9674
# Avg loss (val): 0.0308
# Avg acc (val): 0.8655
# ----------
#
# Epoch 18/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 18 result:
# Avg loss (train): 0.0045
# Avg acc (train): 0.9737
# Avg loss (val): 0.0285
# Avg acc (val): 0.8782
# ----------
#
# Epoch 19/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 19 result:
# Avg loss (train): 0.0043
# Avg acc (train): 0.9726
# Avg loss (val): 0.0302
# Avg acc (val): 0.8782
# ----------
#
# Epoch 20/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 20 result:
# Avg loss (train): 0.0030
# Avg acc (train): 0.9832
# Avg loss (val): 0.0252
# Avg acc (val): 0.9034
# ----------
#
# Epoch 21/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 21 result:
# Avg loss (train): 0.0015
# Avg acc (train): 0.9926
# Avg loss (val): 0.0404
# Avg acc (val): 0.8739
# ----------
#
# Epoch 22/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 22 result:
# Avg loss (train): 0.0025
# Avg acc (train): 0.9874
# Avg loss (val): 0.0396
# Avg acc (val): 0.8824
# ----------
#
# Epoch 23/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 23 result:
# Avg loss (train): 0.0022
# Avg acc (train): 0.9884
# Avg loss (val): 0.0310
# Avg acc (val): 0.8866
# ----------
#
# Epoch 24/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 24 result:
# Avg loss (train): 0.0016
# Avg acc (train): 0.9905
# Avg loss (val): 0.0320
# Avg acc (val): 0.8571
# ----------
#
# Epoch 25/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 25 result:
# Avg loss (train): 0.0022
# Avg acc (train): 0.9863
# Avg loss (val): 0.0316
# Avg acc (val): 0.9034
# ----------
#
# Epoch 26/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 26 result:
# Avg loss (train): 0.0011
# Avg acc (train): 0.9916
# Avg loss (val): 0.0333
# Avg acc (val): 0.8824
# ----------
#
# Epoch 27/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 27 result:
# Avg loss (train): 0.0005
# Avg acc (train): 0.9989
# Avg loss (val): 0.0511
# Avg acc (val): 0.8782
# ----------
#
# Epoch 28/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 28 result:
# Avg loss (train): 0.0016
# Avg acc (train): 0.9905
# Avg loss (val): 0.0416
# Avg acc (val): 0.8908
# ----------
#
# Epoch 29/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 29 result:
# Avg loss (train): 0.0008
# Avg acc (train): 0.9947
# Avg loss (val): 0.0382
# Avg acc (val): 0.8992
# ----------
#
# Epoch 30/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 30 result:
# Avg loss (train): 0.0019
# Avg acc (train): 0.9884
# Avg loss (val): 0.0349
# Avg acc (val): 0.8782
# ----------
#
# Epoch 31/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 31 result:
# Avg loss (train): 0.0035
# Avg acc (train): 0.9789
# Avg loss (val): 0.0327
# Avg acc (val): 0.8992
# ----------
#
# Epoch 32/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 32 result:
# Avg loss (train): 0.0006
# Avg acc (train): 0.9979
# Avg loss (val): 0.0390
# Avg acc (val): 0.9118
# ----------
#
# Epoch 33/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 33 result:
# Avg loss (train): 0.0004
# Avg acc (train): 1.0000
# Avg loss (val): 0.0341
# Avg acc (val): 0.8992
# ----------
#
# Epoch 34/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 34 result:
# Avg loss (train): 0.0027
# Avg acc (train): 0.9832
# Avg loss (val): 0.0844
# Avg acc (val): 0.8067
# ----------
#
# Epoch 35/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 35 result:
# Avg loss (train): 0.0025
# Avg acc (train): 0.9842
# Avg loss (val): 0.0237
# Avg acc (val): 0.9202
# ----------
#
# Epoch 36/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 36 result:
# Avg loss (train): 0.0009
# Avg acc (train): 0.9958
# Avg loss (val): 0.0255
# Avg acc (val): 0.9244
# ----------
#
# Epoch 37/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 37 result:
# Avg loss (train): 0.0007
# Avg acc (train): 0.9958
# Avg loss (val): 0.0386
# Avg acc (val): 0.9118
# ----------
#
# Epoch 38/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 38 result:
# Avg loss (train): 0.0010
# Avg acc (train): 0.9958
# Avg loss (val): 0.0331
# Avg acc (val): 0.9034
# ----------
#
# Epoch 39/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 39 result:
# Avg loss (train): 0.0002
# Avg acc (train): 0.9989
# Avg loss (val): 0.0315
# Avg acc (val): 0.9244
# ----------
#
# Epoch 40/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 40 result:
# Avg loss (train): 0.0002
# Avg acc (train): 0.9989
# Avg loss (val): 0.0366
# Avg acc (val): 0.9160
# ----------
#
# Epoch 41/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 41 result:
# Avg loss (train): 0.0003
# Avg acc (train): 1.0000
# Avg loss (val): 0.0437
# Avg acc (val): 0.9034
# ----------
#
# Epoch 42/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 42 result:
# Avg loss (train): 0.0002
# Avg acc (train): 1.0000
# Avg loss (val): 0.0312
# Avg acc (val): 0.9160
# ----------
#
# Epoch 43/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 43 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0394
# Avg acc (val): 0.9118
# ----------
#
# Epoch 44/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 44 result:
# Avg loss (train): 0.0023
# Avg acc (train): 0.9874
# Avg loss (val): 0.0429
# Avg acc (val): 0.8950
# ----------
#
# Epoch 45/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 45 result:
# Avg loss (train): 0.0017
# Avg acc (train): 0.9937
# Avg loss (val): 0.0575
# Avg acc (val): 0.8655
# ----------
#
# Epoch 46/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 46 result:
# Avg loss (train): 0.0009
# Avg acc (train): 0.9968
# Avg loss (val): 0.0373
# Avg acc (val): 0.9160
# ----------
#
# Epoch 47/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 47 result:
# Avg loss (train): 0.0010
# Avg acc (train): 0.9958
# Avg loss (val): 0.0328
# Avg acc (val): 0.9076
# ----------
#
# Epoch 48/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 48 result:
# Avg loss (train): 0.0002
# Avg acc (train): 1.0000
# Avg loss (val): 0.0333
# Avg acc (val): 0.9160
# ----------
#
# Epoch 49/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 49 result:
# Avg loss (train): 0.0002
# Avg acc (train): 0.9989
# Avg loss (val): 0.0475
# Avg acc (val): 0.9034
# ----------
#
# Epoch 50/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 50 result:
# Avg loss (train): 0.0029
# Avg acc (train): 0.9853
# Avg loss (val): 0.0286
# Avg acc (val): 0.9160
# ----------
#
# Epoch 51/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 51 result:
# Avg loss (train): 0.0003
# Avg acc (train): 1.0000
# Avg loss (val): 0.0320
# Avg acc (val): 0.9160
# ----------
#
# Epoch 52/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 52 result:
# Avg loss (train): 0.0002
# Avg acc (train): 1.0000
# Avg loss (val): 0.0449
# Avg acc (val): 0.9118
# ----------
#
# Epoch 53/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 53 result:
# Avg loss (train): 0.0009
# Avg acc (train): 0.9958
# Avg loss (val): 0.0466
# Avg acc (val): 0.9034
# ----------
#
# Epoch 54/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 54 result:
# Avg loss (train): 0.0010
# Avg acc (train): 0.9958
# Avg loss (val): 0.0422
# Avg acc (val): 0.8824
# ----------
#
# Epoch 55/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 55 result:
# Avg loss (train): 0.0005
# Avg acc (train): 0.9968
# Avg loss (val): 0.0490
# Avg acc (val): 0.8739
# ----------
#
# Epoch 56/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 56 result:
# Avg loss (train): 0.0009
# Avg acc (train): 0.9968
# Avg loss (val): 0.0534
# Avg acc (val): 0.8992
# ----------
#
# Epoch 57/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 57 result:
# Avg loss (train): 0.0016
# Avg acc (train): 0.9895
# Avg loss (val): 0.0624
# Avg acc (val): 0.8697
# ----------
#
# Epoch 58/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 58 result:
# Avg loss (train): 0.0018
# Avg acc (train): 0.9937
# Avg loss (val): 0.0423
# Avg acc (val): 0.8908
# ----------
#
# Epoch 59/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 59 result:
# Avg loss (train): 0.0006
# Avg acc (train): 0.9958
# Avg loss (val): 0.0349
# Avg acc (val): 0.9160
# ----------
#
# Epoch 60/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 60 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0407
# Avg acc (val): 0.9076
# ----------
#
# Epoch 61/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 61 result:
# Avg loss (train): 0.0003
# Avg acc (train): 0.9968
# Avg loss (val): 0.0505
# Avg acc (val): 0.9076
# ----------
#
# Epoch 62/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 62 result:
# Avg loss (train): 0.0004
# Avg acc (train): 0.9968
# Avg loss (val): 0.0574
# Avg acc (val): 0.8992
# ----------
#
# Epoch 63/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 63 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0439
# Avg acc (val): 0.9244
# ----------
#
# Epoch 64/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 64 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0447
# Avg acc (val): 0.9328
# ----------
#
# Epoch 65/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 65 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0480
# Avg acc (val): 0.9118
# ----------
#
# Epoch 66/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 66 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0467
# Avg acc (val): 0.8950
# ----------
#
# Epoch 67/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 67 result:
# Avg loss (train): 0.0015
# Avg acc (train): 0.9916
# Avg loss (val): 0.0546
# Avg acc (val): 0.8866
# ----------
#
# Epoch 68/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 68 result:
# Avg loss (train): 0.0012
# Avg acc (train): 0.9926
# Avg loss (val): 0.0361
# Avg acc (val): 0.9118
# ----------
#
# Epoch 69/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 69 result:
# Avg loss (train): 0.0007
# Avg acc (train): 0.9979
# Avg loss (val): 0.0340
# Avg acc (val): 0.8908
# ----------
#
# Epoch 70/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 70 result:
# Avg loss (train): 0.0003
# Avg acc (train): 0.9979
# Avg loss (val): 0.0371
# Avg acc (val): 0.8992
# ----------
#
# Epoch 71/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 71 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0534
# Avg acc (val): 0.8908
# ----------
#
# Epoch 72/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 72 result:
# Avg loss (train): 0.0015
# Avg acc (train): 0.9895
# Avg loss (val): 0.0492
# Avg acc (val): 0.8571
# ----------
#
# Epoch 73/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 73 result:
# Avg loss (train): 0.0047
# Avg acc (train): 0.9737
# Avg loss (val): 0.0292
# Avg acc (val): 0.9076
# ----------
#
# Epoch 74/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 74 result:
# Avg loss (train): 0.0018
# Avg acc (train): 0.9905
# Avg loss (val): 0.0285
# Avg acc (val): 0.9076
# ----------
#
# Epoch 75/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 75 result:
# Avg loss (train): 0.0005
# Avg acc (train): 0.9979
# Avg loss (val): 0.0370
# Avg acc (val): 0.8950
# ----------
#
# Epoch 76/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 76 result:
# Avg loss (train): 0.0009
# Avg acc (train): 0.9916
# Avg loss (val): 0.0299
# Avg acc (val): 0.8992
# ----------
#
# Epoch 77/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 77 result:
# Avg loss (train): 0.0003
# Avg acc (train): 0.9979
# Avg loss (val): 0.0340
# Avg acc (val): 0.9118
# ----------
#
# Epoch 78/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 78 result:
# Avg loss (train): 0.0003
# Avg acc (train): 0.9979
# Avg loss (val): 0.0463
# Avg acc (val): 0.8950
# ----------
#
# Epoch 79/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 79 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0324
# Avg acc (val): 0.9118
# ----------
#
# Epoch 80/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 80 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0406
# Avg acc (val): 0.9118
# ----------
#
# Epoch 81/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 81 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0384
# Avg acc (val): 0.9244
# ----------
#
# Epoch 82/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 82 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0447
# Avg acc (val): 0.9202
# ----------
#
# Epoch 83/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 83 result:
# Avg loss (train): 0.0002
# Avg acc (train): 0.9989
# Avg loss (val): 0.0543
# Avg acc (val): 0.9118
# ----------
#
# Epoch 84/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 84 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0532
# Avg acc (val): 0.9076
# ----------
#
# Epoch 85/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 85 result:
# Avg loss (train): 0.0010
# Avg acc (train): 0.9958
# Avg loss (val): 0.0396
# Avg acc (val): 0.9160
# ----------
#
# Epoch 86/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 86 result:
# Avg loss (train): 0.0026
# Avg acc (train): 0.9853
# Avg loss (val): 0.0348
# Avg acc (val): 0.8866
# ----------
#
# Epoch 87/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 87 result:
# Avg loss (train): 0.0004
# Avg acc (train): 0.9979
# Avg loss (val): 0.0434
# Avg acc (val): 0.8824
# ----------
#
# Epoch 88/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 88 result:
# Avg loss (train): 0.0005
# Avg acc (train): 0.9958
# Avg loss (val): 0.0390
# Avg acc (val): 0.9160
# ----------
#
# Epoch 89/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 89 result:
# Avg loss (train): 0.0009
# Avg acc (train): 0.9937
# Avg loss (val): 0.0375
# Avg acc (val): 0.9118
# ----------
#
# Epoch 90/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 90 result:
# Avg loss (train): 0.0011
# Avg acc (train): 0.9968
# Avg loss (val): 0.0304
# Avg acc (val): 0.8908
# ----------
#
# Epoch 91/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 91 result:
# Avg loss (train): 0.0007
# Avg acc (train): 0.9947
# Avg loss (val): 0.0344
# Avg acc (val): 0.8950
# ----------
#
# Epoch 92/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 92 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0403
# Avg acc (val): 0.9076
# ----------
#
# Epoch 93/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 93 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0420
# Avg acc (val): 0.9076
# ----------
#
# Epoch 94/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 94 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0419
# Avg acc (val): 0.9076
# ----------
#
# Epoch 95/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 95 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0383
# Avg acc (val): 0.9244
# ----------
#
# Epoch 96/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 96 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0422
# Avg acc (val): 0.9202
# ----------
#
# Epoch 97/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 97 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0456
# Avg acc (val): 0.9160
# ----------
#
# Epoch 98/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 98 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0472
# Avg acc (val): 0.9202
# ----------
#
# Epoch 99/100
# ----------
# Training batch 50/60
# Validation batch 10/15
# Epoch 99 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0420
# Avg acc (val): 0.9202
# ----------
#
#
# Training completed in 76m 34s
# Best acc: 0.9328

# %%
eval_model(vgg19, criterion)
# Out:
# Evaluating model
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Test batch 10/15
# Evaluation completed in 0m 4s
# Avg loss (test): 0.0464
# Avg acc (test): 0.9160
# ----------

# %%
visualize_model(vgg19, num_images=32)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Ground truth:
# Prediction:
# Ground truth:
# Prediction:

# %%
plot_results(history)
