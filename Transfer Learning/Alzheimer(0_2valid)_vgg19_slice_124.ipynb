# %% [markdown]
# <a href="https://colab.research.google.com/github/TaraRasti/Master-Thesis/blob/main/Transfer%20Learning/Alzheimer(0_2valid)_vgg19_slice_124.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from __future__ import print_function, division
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.autograd import Variable
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from torchvision.datasets import ImageFolder
from torch.utils.data import Subset
from sklearn.model_selection import train_test_split
from torchvision.transforms import Compose, ToTensor, Resize
from torch.utils.data import DataLoader
from collections import defaultdict

plt.ion()  

use_gpu = torch.cuda.is_available()
if use_gpu:
    print("Using CUDA")
# Out:
# Using CUDA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
transform = transforms.Compose( [                                  
                                 transforms.Resize((224,224)),
                                 transforms.RandomRotation(10),
                                 transforms.RandomHorizontalFlip(), 
                                 transforms.ToTensor(),
                                  ])

def train_val_dataset(dataset, val_split=0.2):
    train_idx, val_idx = train_test_split(list(range(len(dataset))), test_size=val_split)
    datasets = {}
    datasets['train'] = Subset(dataset, train_idx)
    datasets['val'] = Subset(dataset, val_idx)
    return datasets

dataset = ImageFolder('/content/drive/MyDrive/124', transform=transform)
print('length of dataset :',len(dataset))
datasets = train_val_dataset(dataset)
print('length of trainset :',len(datasets['train']))
print('length of validation set :',len(datasets['val']))
print(dataset)
# Out:
# length of dataset : 604
# length of trainset : 483
# length of validation set : 121
# Dataset ImageFolder
#     Number of datapoints: 604
#     Root location: /content/drive/MyDrive/124
#     StandardTransform
# Transform: Compose(
#                Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=None)
#                RandomRotation(degrees=[-10.0, 10.0], interpolation=nearest, expand=False, fill=0)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#            )

# %%
dataloaders = {x:DataLoader(datasets[x], 16, shuffle=True, num_workers=4) for x in ['train','val']}
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
inputs, classes = next(iter(dataloaders['train']))
print(inputs.shape, classes.shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# torch.Size([16, 3, 224, 224]) torch.Size([16])

# %%
class_names = dataset.classes
print(class_names)
# Out:
# ['demented', 'normal']

# %%
dataset_sizes={'val':len(datasets['val']),'train':len(datasets['train'])}

# %%
def imshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    plt.figure(figsize=(25, 25))
    plt.axis('off')
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

def show_databatch(inputs, classes):
    out = torchvision.utils.make_grid(inputs)
    imshow(out, title=[class_names[x] for x in classes])

show_databatch(inputs, classes)

# %%
def visualize_model(vgg, num_images=6):
    was_training = vgg.training
    
    vgg.train(False)
    vgg.eval() 
    
    images_so_far = 0

    for i, data in enumerate(dataloaders['val']):
        inputs, labels = data
        size = inputs.size()[0]
        
        if use_gpu:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)
        
        outputs = vgg(inputs)
        
        _, preds = torch.max(outputs.data, 1)
        predicted_labels = [preds[j] for j in range(inputs.size()[0])]
        
        print("Ground truth:")
        show_databatch(inputs.data.cpu(), labels.data.cpu())
        print("Prediction:")
        show_databatch(inputs.data.cpu(), predicted_labels)
        
        del inputs, labels, outputs, preds, predicted_labels
        torch.cuda.empty_cache()
        
        images_so_far += size
        if images_so_far >= num_images:
            break
        
    vgg.train(mode=was_training)

# %%
def eval_model(vgg, criterion):
    since = time.time()
    avg_loss = 0
    avg_acc = 0
    loss_test = 0
    acc_test = 0
    
    test_batches = len(dataloaders['val'])
    print("Evaluating model")
    print('-' * 10)
    
    for i, data in enumerate(dataloaders['val']):
        if i % 10 == 0:
            print("\rTest batch {}/{}".format(i, test_batches), end='', flush=True)

        vgg.train(False)
        vgg.eval()
        inputs, labels = data

        if use_gpu:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)

        outputs = vgg(inputs)

        _, preds = torch.max(outputs.data, 1)
        loss = criterion(outputs, labels)

        loss_test += loss.item()
        acc_test += torch.sum(preds == labels.data).item()

        del inputs, labels, outputs, preds
        torch.cuda.empty_cache()
        
    avg_loss = loss_test / dataset_sizes['val']
    avg_acc = acc_test / dataset_sizes['val']
    
    elapsed_time = time.time() - since
    print()
    print("Evaluation completed in {:.0f}m {:.0f}s".format(elapsed_time // 60, elapsed_time % 60))
    print("Avg loss (test): {:.4f}".format(avg_loss))
    print("Avg acc (test): {:.4f}".format(avg_acc))
    print('-' * 10)

# %%
vgg19 = models.vgg19(pretrained=True)
print(vgg19.classifier[6].out_features)  


for param in vgg19.features.parameters():
    param.require_grad = False


num_features = vgg19.classifier[6].in_features
features = list(vgg19.classifier.children())[:-1] 
features.extend([nn.Linear(num_features, len(class_names))])
vgg19.classifier = nn.Sequential(*features)
print(vgg19)
# Out:
# 1000
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %%
if use_gpu:
    vgg19.cuda()
    
criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.Adam(vgg19.parameters(), lr=1e-5, weight_decay=1e-5)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
print("Test before training")
eval_model(vgg19, criterion)
# Out:
# Test before training
# Evaluating model
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Test batch 0/8
# Evaluation completed in 0m 3s
# Avg loss (test): 0.0382
# Avg acc (test): 0.7851
# ----------

# %%
history = defaultdict(list)

# %%
def train_model(vgg, criterion, optimizer, scheduler, num_epochs):
    since = time.time()
    best_model_wts = copy.deepcopy(vgg.state_dict())
    best_acc = 0.0
    
    avg_loss = 0
    avg_acc = 0
    avg_loss_val = 0
    avg_acc_val = 0
    
    train_batches = len(dataloaders['train'])
    val_batches = len(dataloaders['val'])
    
    for epoch in range(num_epochs):
        print("Epoch {}/{}".format(epoch, num_epochs))
        print('-' * 10)
        
        loss_train = 0
        loss_val = 0
        acc_train = 0
        acc_val = 0
        
        vgg.train(True)
        
        for i, data in enumerate(dataloaders['train']):
            if i % 10 == 0:
                print("\rTraining batch {}/{}".format(i, train_batches), end='', flush=True)
                
            if i >= train_batches:
                break
                
            inputs, labels = data
            
            if use_gpu:
                inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
            else:
                inputs, labels = Variable(inputs), Variable(labels)
            
            optimizer.zero_grad()
            
            outputs = vgg(inputs)
            
            _, preds = torch.max(outputs.data, 1)
            loss = criterion(outputs, labels)
            
            loss.backward()
            optimizer.step()
            
            loss_train += loss.item()
            acc_train += torch.sum(preds == labels.data).item()
            
            del inputs, labels, outputs, preds
            torch.cuda.empty_cache()
        
        print()

        avg_loss = loss_train / dataset_sizes['train']
        avg_acc = acc_train / dataset_sizes['train']
        
        vgg.train(False)
        vgg.eval()
            
        for i, data in enumerate(dataloaders['val']):
            if i % 10 == 0:
                print("\rValidation batch {}/{}".format(i, val_batches), end='', flush=True)
                
            inputs, labels = data
            
            if use_gpu:
                inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
            else:
                inputs, labels = Variable(inputs), Variable(labels)
            
            optimizer.zero_grad()
            
            outputs = vgg(inputs)
            
            _, preds = torch.max(outputs.data, 1)
            loss = criterion(outputs, labels)

            loss_val += loss.item()
            acc_val += torch.sum(preds == labels.data).item()

            del inputs, labels, outputs, preds
            torch.cuda.empty_cache()
        
        avg_loss_val = loss_val / dataset_sizes['val']
        avg_acc_val = acc_val / dataset_sizes['val']
        
        print()
        print("Epoch {} result: ".format(epoch))
        print("Avg loss (train): {:.4f}".format(avg_loss))
        print("Avg acc (train): {:.4f}".format(avg_acc))
        print("Avg loss (val): {:.4f}".format(avg_loss_val))
        print("Avg acc (val): {:.4f}".format(avg_acc_val))
        print('-' * 10)
        print()

        history['epoch'].append(epoch+1)
        history['avg_loss'].append(round(avg_loss,5))
        history['avg_acc'].append(round(avg_acc,5))
        history['avg_loss_val'].append(round(avg_loss_val,5))
        history['avg_acc_val'].append(round(avg_acc_val,5))
    
        
        if avg_acc_val > best_acc:
            best_acc = avg_acc_val
            best_model_wts = copy.deepcopy(vgg.state_dict())
        
    elapsed_time = time.time() - since
    print()
    print("Training completed in {:.0f}m {:.0f}s".format(elapsed_time // 60, elapsed_time % 60))
    print("Best acc: {:.4f}".format(best_acc))
    
    vgg.load_state_dict(best_model_wts)
    return vgg

# %%
def plot_results(history):
    avg_acc = history['avg_acc']
    avg_acc_val = history['avg_acc_val']
    avg_loss = history['avg_loss']
    avg_loss_val = history['avg_loss_val']
    epochs = history['epoch']

    plt.figure(figsize = (24, 6))
    plt.subplot(1,2,1)
    plt.plot(epochs, avg_acc, 'b', label = 'Training Accuracy')
    plt.plot(epochs, avg_acc_val, 'r', label = 'Validation Accuracy')
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')  
    
    plt.subplot(1,2,2)
    plt.plot(epochs, avg_loss, 'b', label = 'Training Loss')
    plt.plot(epochs, avg_loss_val, 'r', label = 'Validation Loss')
    plt.grid(True)
    plt.legend()
    plt.xlabel('Epoch')
    plt.show()

# %%
vgg19 = train_model(vgg19, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=100)
# Out:
# Epoch 0/100
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Training batch 30/31
# Validation batch 0/8
# Epoch 0 result:
# Avg loss (train): 0.0389
# Avg acc (train): 0.7474
# Avg loss (val): 0.0361
# Avg acc (val): 0.7851
# ----------
#
# Epoch 1/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 1 result:
# Avg loss (train): 0.0361
# Avg acc (train): 0.7412
# Avg loss (val): 0.0319
# Avg acc (val): 0.7851
# ----------
#
# Epoch 2/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 2 result:
# Avg loss (train): 0.0329
# Avg acc (train): 0.7474
# Avg loss (val): 0.0297
# Avg acc (val): 0.8182
# ----------
#
# Epoch 3/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 3 result:
# Avg loss (train): 0.0304
# Avg acc (train): 0.7412
# Avg loss (val): 0.0275
# Avg acc (val): 0.8182
# ----------
#
# Epoch 4/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 4 result:
# Avg loss (train): 0.0275
# Avg acc (train): 0.8095
# Avg loss (val): 0.0262
# Avg acc (val): 0.8182
# ----------
#
# Epoch 5/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 5 result:
# Avg loss (train): 0.0277
# Avg acc (train): 0.8012
# Avg loss (val): 0.0258
# Avg acc (val): 0.8430
# ----------
#
# Epoch 6/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 6 result:
# Avg loss (train): 0.0253
# Avg acc (train): 0.8199
# Avg loss (val): 0.0258
# Avg acc (val): 0.8264
# ----------
#
# Epoch 7/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 7 result:
# Avg loss (train): 0.0242
# Avg acc (train): 0.8427
# Avg loss (val): 0.0274
# Avg acc (val): 0.8099
# ----------
#
# Epoch 8/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 8 result:
# Avg loss (train): 0.0233
# Avg acc (train): 0.8240
# Avg loss (val): 0.0257
# Avg acc (val): 0.8264
# ----------
#
# Epoch 9/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 9 result:
# Avg loss (train): 0.0219
# Avg acc (train): 0.8592
# Avg loss (val): 0.0327
# Avg acc (val): 0.7686
# ----------
#
# Epoch 10/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 10 result:
# Avg loss (train): 0.0243
# Avg acc (train): 0.8137
# Avg loss (val): 0.0275
# Avg acc (val): 0.8099
# ----------
#
# Epoch 11/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 11 result:
# Avg loss (train): 0.0191
# Avg acc (train): 0.8923
# Avg loss (val): 0.0256
# Avg acc (val): 0.8264
# ----------
#
# Epoch 12/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 12 result:
# Avg loss (train): 0.0193
# Avg acc (train): 0.8758
# Avg loss (val): 0.0254
# Avg acc (val): 0.8099
# ----------
#
# Epoch 13/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 13 result:
# Avg loss (train): 0.0149
# Avg acc (train): 0.9110
# Avg loss (val): 0.0280
# Avg acc (val): 0.8099
# ----------
#
# Epoch 14/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 14 result:
# Avg loss (train): 0.0157
# Avg acc (train): 0.8923
# Avg loss (val): 0.0319
# Avg acc (val): 0.7686
# ----------
#
# Epoch 15/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 15 result:
# Avg loss (train): 0.0131
# Avg acc (train): 0.9193
# Avg loss (val): 0.0326
# Avg acc (val): 0.7521
# ----------
#
# Epoch 16/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 16 result:
# Avg loss (train): 0.0129
# Avg acc (train): 0.9255
# Avg loss (val): 0.0333
# Avg acc (val): 0.8430
# ----------
#
# Epoch 17/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 17 result:
# Avg loss (train): 0.0111
# Avg acc (train): 0.9420
# Avg loss (val): 0.0354
# Avg acc (val): 0.7521
# ----------
#
# Epoch 18/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 18 result:
# Avg loss (train): 0.0076
# Avg acc (train): 0.9565
# Avg loss (val): 0.0450
# Avg acc (val): 0.7273
# ----------
#
# Epoch 19/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 19 result:
# Avg loss (train): 0.0065
# Avg acc (train): 0.9669
# Avg loss (val): 0.0351
# Avg acc (val): 0.8099
# ----------
#
# Epoch 20/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 20 result:
# Avg loss (train): 0.0074
# Avg acc (train): 0.9689
# Avg loss (val): 0.0443
# Avg acc (val): 0.8182
# ----------
#
# Epoch 21/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 21 result:
# Avg loss (train): 0.0140
# Avg acc (train): 0.8944
# Avg loss (val): 0.0404
# Avg acc (val): 0.7603
# ----------
#
# Epoch 22/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 22 result:
# Avg loss (train): 0.0058
# Avg acc (train): 0.9627
# Avg loss (val): 0.0451
# Avg acc (val): 0.7438
# ----------
#
# Epoch 23/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 23 result:
# Avg loss (train): 0.0034
# Avg acc (train): 0.9772
# Avg loss (val): 0.0330
# Avg acc (val): 0.8017
# ----------
#
# Epoch 24/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 24 result:
# Avg loss (train): 0.0018
# Avg acc (train): 0.9938
# Avg loss (val): 0.0487
# Avg acc (val): 0.7851
# ----------
#
# Epoch 25/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 25 result:
# Avg loss (train): 0.0025
# Avg acc (train): 0.9855
# Avg loss (val): 0.0553
# Avg acc (val): 0.8182
# ----------
#
# Epoch 26/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 26 result:
# Avg loss (train): 0.0015
# Avg acc (train): 0.9917
# Avg loss (val): 0.0534
# Avg acc (val): 0.8017
# ----------
#
# Epoch 27/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 27 result:
# Avg loss (train): 0.0028
# Avg acc (train): 0.9772
# Avg loss (val): 0.0483
# Avg acc (val): 0.8017
# ----------
#
# Epoch 28/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 28 result:
# Avg loss (train): 0.0038
# Avg acc (train): 0.9752
# Avg loss (val): 0.0419
# Avg acc (val): 0.7851
# ----------
#
# Epoch 29/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 29 result:
# Avg loss (train): 0.0017
# Avg acc (train): 0.9855
# Avg loss (val): 0.0456
# Avg acc (val): 0.8182
# ----------
#
# Epoch 30/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 30 result:
# Avg loss (train): 0.0020
# Avg acc (train): 0.9896
# Avg loss (val): 0.0487
# Avg acc (val): 0.8017
# ----------
#
# Epoch 31/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 31 result:
# Avg loss (train): 0.0039
# Avg acc (train): 0.9731
# Avg loss (val): 0.0521
# Avg acc (val): 0.7438
# ----------
#
# Epoch 32/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 32 result:
# Avg loss (train): 0.0013
# Avg acc (train): 0.9917
# Avg loss (val): 0.0591
# Avg acc (val): 0.7769
# ----------
#
# Epoch 33/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 33 result:
# Avg loss (train): 0.0015
# Avg acc (train): 0.9917
# Avg loss (val): 0.0658
# Avg acc (val): 0.7934
# ----------
#
# Epoch 34/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 34 result:
# Avg loss (train): 0.0039
# Avg acc (train): 0.9710
# Avg loss (val): 0.0525
# Avg acc (val): 0.7934
# ----------
#
# Epoch 35/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 35 result:
# Avg loss (train): 0.0014
# Avg acc (train): 0.9917
# Avg loss (val): 0.0404
# Avg acc (val): 0.8182
# ----------
#
# Epoch 36/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 36 result:
# Avg loss (train): 0.0004
# Avg acc (train): 1.0000
# Avg loss (val): 0.0590
# Avg acc (val): 0.8347
# ----------
#
# Epoch 37/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 37 result:
# Avg loss (train): 0.0010
# Avg acc (train): 0.9917
# Avg loss (val): 0.0644
# Avg acc (val): 0.7686
# ----------
#
# Epoch 38/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 38 result:
# Avg loss (train): 0.0003
# Avg acc (train): 0.9979
# Avg loss (val): 0.0630
# Avg acc (val): 0.7686
# ----------
#
# Epoch 39/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 39 result:
# Avg loss (train): 0.0003
# Avg acc (train): 0.9979
# Avg loss (val): 0.0810
# Avg acc (val): 0.7603
# ----------
#
# Epoch 40/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 40 result:
# Avg loss (train): 0.0007
# Avg acc (train): 0.9959
# Avg loss (val): 0.0602
# Avg acc (val): 0.8264
# ----------
#
# Epoch 41/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 41 result:
# Avg loss (train): 0.0035
# Avg acc (train): 0.9793
# Avg loss (val): 0.0735
# Avg acc (val): 0.7851
# ----------
#
# Epoch 42/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 42 result:
# Avg loss (train): 0.0026
# Avg acc (train): 0.9855
# Avg loss (val): 0.0558
# Avg acc (val): 0.8182
# ----------
#
# Epoch 43/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 43 result:
# Avg loss (train): 0.0005
# Avg acc (train): 0.9979
# Avg loss (val): 0.0645
# Avg acc (val): 0.8099
# ----------
#
# Epoch 44/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 44 result:
# Avg loss (train): 0.0002
# Avg acc (train): 1.0000
# Avg loss (val): 0.0675
# Avg acc (val): 0.8264
# ----------
#
# Epoch 45/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 45 result:
# Avg loss (train): 0.0017
# Avg acc (train): 0.9896
# Avg loss (val): 0.0677
# Avg acc (val): 0.7686
# ----------
#
# Epoch 46/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 46 result:
# Avg loss (train): 0.0018
# Avg acc (train): 0.9938
# Avg loss (val): 0.0625
# Avg acc (val): 0.7851
# ----------
#
# Epoch 47/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 47 result:
# Avg loss (train): 0.0011
# Avg acc (train): 0.9938
# Avg loss (val): 0.0605
# Avg acc (val): 0.8182
# ----------
#
# Epoch 48/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 48 result:
# Avg loss (train): 0.0007
# Avg acc (train): 0.9959
# Avg loss (val): 0.0670
# Avg acc (val): 0.8347
# ----------
#
# Epoch 49/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 49 result:
# Avg loss (train): 0.0006
# Avg acc (train): 0.9979
# Avg loss (val): 0.0623
# Avg acc (val): 0.8264
# ----------
#
# Epoch 50/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 50 result:
# Avg loss (train): 0.0012
# Avg acc (train): 0.9917
# Avg loss (val): 0.0711
# Avg acc (val): 0.8182
# ----------
#
# Epoch 51/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 51 result:
# Avg loss (train): 0.0053
# Avg acc (train): 0.9689
# Avg loss (val): 0.0632
# Avg acc (val): 0.8017
# ----------
#
# Epoch 52/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 52 result:
# Avg loss (train): 0.0009
# Avg acc (train): 0.9959
# Avg loss (val): 0.0513
# Avg acc (val): 0.7851
# ----------
#
# Epoch 53/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 53 result:
# Avg loss (train): 0.0013
# Avg acc (train): 0.9959
# Avg loss (val): 0.0623
# Avg acc (val): 0.8430
# ----------
#
# Epoch 54/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 54 result:
# Avg loss (train): 0.0020
# Avg acc (train): 0.9876
# Avg loss (val): 0.0449
# Avg acc (val): 0.8017
# ----------
#
# Epoch 55/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 55 result:
# Avg loss (train): 0.0018
# Avg acc (train): 0.9896
# Avg loss (val): 0.0641
# Avg acc (val): 0.8017
# ----------
#
# Epoch 56/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 56 result:
# Avg loss (train): 0.0006
# Avg acc (train): 1.0000
# Avg loss (val): 0.0666
# Avg acc (val): 0.8182
# ----------
#
# Epoch 57/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 57 result:
# Avg loss (train): 0.0004
# Avg acc (train): 0.9979
# Avg loss (val): 0.0550
# Avg acc (val): 0.8182
# ----------
#
# Epoch 58/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 58 result:
# Avg loss (train): 0.0004
# Avg acc (train): 0.9979
# Avg loss (val): 0.0634
# Avg acc (val): 0.8264
# ----------
#
# Epoch 59/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 59 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0687
# Avg acc (val): 0.8017
# ----------
#
# Epoch 60/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 60 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0720
# Avg acc (val): 0.8099
# ----------
#
# Epoch 61/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 61 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0659
# Avg acc (val): 0.8182
# ----------
#
# Epoch 62/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 62 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0669
# Avg acc (val): 0.8099
# ----------
#
# Epoch 63/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 63 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0718
# Avg acc (val): 0.7769
# ----------
#
# Epoch 64/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 64 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0705
# Avg acc (val): 0.8182
# ----------
#
# Epoch 65/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 65 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0800
# Avg acc (val): 0.8182
# ----------
#
# Epoch 66/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 66 result:
# Avg loss (train): 0.0007
# Avg acc (train): 0.9959
# Avg loss (val): 0.0822
# Avg acc (val): 0.7934
# ----------
#
# Epoch 67/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 67 result:
# Avg loss (train): 0.0004
# Avg acc (train): 1.0000
# Avg loss (val): 0.0720
# Avg acc (val): 0.8017
# ----------
#
# Epoch 68/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 68 result:
# Avg loss (train): 0.0030
# Avg acc (train): 0.9772
# Avg loss (val): 0.0849
# Avg acc (val): 0.7686
# ----------
#
# Epoch 69/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 69 result:
# Avg loss (train): 0.0011
# Avg acc (train): 0.9959
# Avg loss (val): 0.0745
# Avg acc (val): 0.8017
# ----------
#
# Epoch 70/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 70 result:
# Avg loss (train): 0.0016
# Avg acc (train): 0.9855
# Avg loss (val): 0.0797
# Avg acc (val): 0.7851
# ----------
#
# Epoch 71/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 71 result:
# Avg loss (train): 0.0056
# Avg acc (train): 0.9669
# Avg loss (val): 0.0570
# Avg acc (val): 0.7769
# ----------
#
# Epoch 72/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 72 result:
# Avg loss (train): 0.0022
# Avg acc (train): 0.9917
# Avg loss (val): 0.0563
# Avg acc (val): 0.8099
# ----------
#
# Epoch 73/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 73 result:
# Avg loss (train): 0.0008
# Avg acc (train): 0.9938
# Avg loss (val): 0.0596
# Avg acc (val): 0.7851
# ----------
#
# Epoch 74/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 74 result:
# Avg loss (train): 0.0004
# Avg acc (train): 0.9959
# Avg loss (val): 0.0749
# Avg acc (val): 0.8099
# ----------
#
# Epoch 75/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 75 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0631
# Avg acc (val): 0.7934
# ----------
#
# Epoch 76/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 76 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0523
# Avg acc (val): 0.8099
# ----------
#
# Epoch 77/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 77 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0725
# Avg acc (val): 0.7934
# ----------
#
# Epoch 78/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 78 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0712
# Avg acc (val): 0.8099
# ----------
#
# Epoch 79/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 79 result:
# Avg loss (train): 0.0017
# Avg acc (train): 0.9896
# Avg loss (val): 0.1013
# Avg acc (val): 0.8264
# ----------
#
# Epoch 80/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 80 result:
# Avg loss (train): 0.0037
# Avg acc (train): 0.9731
# Avg loss (val): 0.0600
# Avg acc (val): 0.8099
# ----------
#
# Epoch 81/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 81 result:
# Avg loss (train): 0.0004
# Avg acc (train): 0.9979
# Avg loss (val): 0.0748
# Avg acc (val): 0.8264
# ----------
#
# Epoch 82/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 82 result:
# Avg loss (train): 0.0003
# Avg acc (train): 1.0000
# Avg loss (val): 0.0586
# Avg acc (val): 0.8182
# ----------
#
# Epoch 83/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 83 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0626
# Avg acc (val): 0.8099
# ----------
#
# Epoch 84/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 84 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0669
# Avg acc (val): 0.8182
# ----------
#
# Epoch 85/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 85 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0751
# Avg acc (val): 0.8347
# ----------
#
# Epoch 86/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 86 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0621
# Avg acc (val): 0.8347
# ----------
#
# Epoch 87/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 87 result:
# Avg loss (train): 0.0001
# Avg acc (train): 0.9979
# Avg loss (val): 0.0735
# Avg acc (val): 0.8099
# ----------
#
# Epoch 88/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 88 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0619
# Avg acc (val): 0.8347
# ----------
#
# Epoch 89/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 89 result:
# Avg loss (train): 0.0001
# Avg acc (train): 1.0000
# Avg loss (val): 0.0880
# Avg acc (val): 0.7769
# ----------
#
# Epoch 90/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 90 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0772
# Avg acc (val): 0.8430
# ----------
#
# Epoch 91/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 91 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0730
# Avg acc (val): 0.8264
# ----------
#
# Epoch 92/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 92 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0704
# Avg acc (val): 0.8017
# ----------
#
# Epoch 93/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 93 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0806
# Avg acc (val): 0.8099
# ----------
#
# Epoch 94/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 94 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0747
# Avg acc (val): 0.8099
# ----------
#
# Epoch 95/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 95 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.1073
# Avg acc (val): 0.7851
# ----------
#
# Epoch 96/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 96 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0824
# Avg acc (val): 0.8264
# ----------
#
# Epoch 97/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 97 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0806
# Avg acc (val): 0.8182
# ----------
#
# Epoch 98/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 98 result:
# Avg loss (train): 0.0002
# Avg acc (train): 0.9979
# Avg loss (val): 0.0681
# Avg acc (val): 0.8182
# ----------
#
# Epoch 99/100
# ----------
# Training batch 30/31
# Validation batch 0/8
# Epoch 99 result:
# Avg loss (train): 0.0000
# Avg acc (train): 1.0000
# Avg loss (val): 0.0685
# Avg acc (val): 0.8264
# ----------
#
#
# Training completed in 41m 52s
# Best acc: 0.8430

# %%
eval_model(vgg19, criterion)
# Out:
# Evaluating model
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Test batch 0/8
# Evaluation completed in 0m 3s
# Avg loss (test): 0.0252
# Avg acc (test): 0.8182
# ----------

# %%
visualize_model(vgg19, num_images=32)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Ground truth:
# Prediction:
# Ground truth:
# Prediction:

# %%
plot_results(history)
