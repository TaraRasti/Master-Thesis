# %%
from PIL import Image
from matplotlib import image
from matplotlib import pyplot
import os
import numpy as np

# %%
image = image.imread('/Users/taraapple/Downloads/thesis/ALZHEIMER/demented/sub-OAS30873/156sub-OAS30873.png')
print(image.dtype)
print(image.shape)
pyplot.imshow(image)
pyplot.show()
# Out:
# float32
# (176, 256)

# %%
l=[]
for i in range(image.shape[0]):
    if len(np.unique(image[i,:]<0.05))==1:
        l.append(i)

# %%
x = np.delete(image, (l), axis=0)

# %%
pyplot.imshow(x)
pyplot.show()

# %%
l=[]
for j in range(image.shape[1]):
    if len(np.unique(image[:,j]<0.05))==1:
        l.append(j)

# %%
x = np.delete(x, (l), axis=1)

# %%
pyplot.imshow(x)
pyplot.show()

# %%
x.shape
# Out:
# (139, 177)
